# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df.head()
df.shape #2. Посмотреть сколько в нем строк и столбцов
df.dtypes #3. Определить какой тип данных имеют столбцы
df.isnull().sum() #Проверить есть ли в файле пустые значения

df[(df['sex'] == 'female') & (df['fare']>150)] #2. Показать ывживший (survived) девушек со стоиомостью билета >150

df[['pclass', 'survived']] #3. Показать данные в первых 2 столбцах

df[((df['pclass'] == 3)&(df['survived'] == 1)) | ((df['pclass'] == 1)&(df['survived'] == 0))] #4. выживших из третьего класса (Pclass) и невыживших из 1-го
# Out:
#       pclass  survived                                             name  \
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7        1.0       0.0                           Andrews, Mr. Thomas Jr
# 9        1.0       0.0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1261     3.0       1.0                           Turkula, Mrs. (Hedwig)
# 1277     3.0       1.0                             Vartanian, Mr. David
# 1286     3.0       1.0  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290     3.0       1.0                 Wilkes, Mrs. James (Ellen Needs)
# 1300     3.0       1.0          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked   boat  \
# ...

# %%
df[(df['sex'] == 'female') & (df['fare']>150)] #2. Показать ывживший (survived) девушек со стоиомостью билета >150
# Out:
#      pclass  survived                                               name  \
# 0       1.0       1.0                      Allen, Miss. Elisabeth Walton
# 2       1.0       0.0                       Allison, Miss. Helen Loraine
# 4       1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 11      1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 17      1.0       1.0    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 23      1.0       1.0                              Bidois, Miss. Rosalie
# 24      1.0       1.0                                  Bird, Miss. Ellen
# 32      1.0       1.0                            Bonnell, Miss. Caroline
# 35      1.0       1.0                           Bowen, Miss. Grace Scott
# 50      1.0       1.0  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 66      1.0       1.0                        Chaudanson, Miss. Victorine
# 73      1.0       1.0                               Cleaver, Miss. Alice
# ...
